# %%
import pandas as pd

# %%
data = pd.read_csv("data/disabilityconfident.csv", encoding="ISO-8859-1")

# %%
data.head()
# Out:
#                                 Business name Town or city Postcode  \
# 0  1 Business Enterprise t/a Get Set Academy     Blackburn      BB2
# 1          1 Less Worry Payroll Services Ltd     Plymouth       PL3
# 2                           1 Stop Healthcare   Colchester      CO3
# 3                        121 Captions Limited       London      W1A
# 4                           1620 PIMM Limited  Southampton     SO16
#
#                  Sector DC level (Committed, Employer, Leader)
# 0  Education / Teaching                              Committed
# 1    Financial Services                              Committed
# 2  Recruitment Agencies                               Employer
# 3      Customer service                              Committed
# 4  Education / Teaching                               Employer

# %%
data['FirstPostcode'] = data['Postcode'].str[:2]

# %%
data.head()
# Out:
#                                 Business name Town or city Postcode  \
# 0  1 Business Enterprise t/a Get Set Academy     Blackburn      BB2
# 1          1 Less Worry Payroll Services Ltd     Plymouth       PL3
# 2                           1 Stop Healthcare   Colchester      CO3
# 3                        121 Captions Limited       London      W1A
# 4                           1620 PIMM Limited  Southampton     SO16
#
#                  Sector DC level (Committed, Employer, Leader) FirstPostcode
# 0  Education / Teaching                              Committed            BB
# 1    Financial Services                              Committed            PL
# 2  Recruitment Agencies                               Employer            CO
# 3      Customer service                              Committed            W1
# 4  Education / Teaching                               Employer            SO

# %%
data['Sector'].value_counts()
# Out:
# Voluntary, Charity & Social Enterprise           2192
# Education / Teaching                             1120
# Administration/Office including Public sector     861
# Other                                             800
# Care/Childcare/Social Care                        779
# Health                                            718
# Hospitality, Leisure and Tourism                  696
# Retail/Sales                                      638
# Manufacturing & Engineering                       399
# Recruitment Agencies                              341
# Construction                                      227
# Arts and Media                                    193
# Information Technology and Telecoms               182
# Transport and logistics                           162
# Financial Services                                136
# Sports & Recreation                               134
# Facilities Management                             126
# Security and Safety                                94
# Beauty and Therapy                                 76
# Energy & Utilities                                 64
# Customer service                                   63
# Agriculture                                        59
# Contact Centres                                    32
# Armed Forces                                        2
# Name: Sector, dtype: int64

# %%
data['Sector'].count()
# Out:
# 10094

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(6,16))

sns.set(style="darkgrid", context="talk")
graph_palette = reversed(sns.cubehelix_palette(24))

sns.countplot(y="Sector", data=data, order=data['Sector'].value_counts().index, linewidth=2, palette=graph_palette)

sns.despine(bottom=True)
ax.set_xlabel("Count of United Kingdom Employers", labelpad=20)
#plt.title("United Kingdom Employers That Have Singed Up With Government Disability Confidence", pad=20)
# Out:
# Text(0.5, 0, 'Count of United Kingdom Employers')

# %%
data['Sector'].unique()
# Out:
# array(['Education / Teaching', 'Financial Services',
#        'Recruitment Agencies', 'Customer service',
#        'Transport and logistics', 'Care/Childcare/Social Care', 'Health',
#        'Other', 'Retail/Sales', 'Manufacturing & Engineering',
#        'Hospitality, Leisure and Tourism',
#        'Voluntary, Charity & Social Enterprise',
#        'Information Technology and Telecoms', 'Facilities Management',
#        'Sports & Recreation', 'Armed Forces', 'Construction',
#        'Beauty and Therapy', 'Security and Safety', 'Agriculture',
#        'Administration/Office including Public sector',
#        'Energy & Utilities', 'Contact Centres', 'Arts and Media'],
#       dtype=object)
